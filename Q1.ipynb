# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
def train_perceptron(x, y, w, nb_epochs_max):  
  for e in range(nb_epochs_max):
    nb_changes = 0
    for i in range(x.size(0)):
      if x[i].dot(w) * y[i] <= 0:
        w = w + y[i] * x[i]
        nb_changes = nb_changes + 1
    #print('Number of changes: %d'%nb_changes) # prints the number of changes every epoch
    if nb_changes == 0:
        print('Early stopping at epoch number %d',e) 
        break
  print('Number of changes: %d'%nb_changes)  # prints the number of chages in the end  
  return w

# %%
# Create data sampling from two Gaussian distributions

D1=torch.normal(0.0, 1.0,size=[500,2])
D2=torch.normal(1.0, 1.0,size=[500,2])

# %%
# plot the data

plt.scatter(D1[:,0], D1[:,1])
plt.scatter(D2[:,0], D2[:,1])

# %%
# Add the extra dimension (1) to data 

X=torch.empty(1000,D1.size(1)+1).fill_(1)
X[::2,:2] = D1
X[1::2,:2] = D2
print(X.shape)

# prepare the labels
Y=torch.empty(1000,1)
Y[::2,:2] = 1.0
Y[1::2,:2] = -1.0
print(Y.shape)
# Out:
# torch.Size([1000, 3])
# torch.Size([1000, 1])

# %%
W = torch.zeros(X.size(1))

# %%
# plot the data and W before training

x = np.linspace(-5,5,100)
y = np.zeros(100,) 
plt.plot(x, y, '-r', label='W')
plt.title('Graph of W before training')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.scatter(D1[:,0], D1[:,1])
plt.scatter(D2[:,0], D2[:,1])
plt.grid()
plt.show()

# %%
W = train_perceptron(X,Y, W, 5)
print(W)
# Out:
# Number of changes: 387
# tensor([-1.6185, -2.0212,  2.0000])

# %%
x = np.linspace(-5,5,100)
y = -(W[0].item()/W[1].item())*x - (W[2].item()/W[1].item())
plt.plot(x, y, '-r', label='W')
plt.title('Graph of W after training for gamma = ')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.scatter(D1[:,0], D1[:,1])
plt.scatter(D2[:,0], D2[:,1])
plt.grid()
plt.show()

# %%
# Create data sampling from two Gaussian distributions

D1=torch.normal(0.0, 1.0,size=[500,2])
D2=torch.normal(3.0, 1.0,size=[500,2])

# %%
# plot the data

plt.scatter(D1[:,0], D1[:,1])
plt.scatter(D2[:,0], D2[:,1])

# %%
# Add the extra dimension (1) to data 

X=torch.empty(1000,D1.size(1)+1).fill_(1)
X[::2,:2] = D1
X[1::2,:2] = D2
print(X.shape)

# prepare the labels
Y=torch.empty(1000,1)
Y[::2,:2] = 1.0
Y[1::2,:2] = -1.0
print(Y.shape)
# Out:
# torch.Size([1000, 3])
# torch.Size([1000, 1])

# %%
W = torch.zeros(X.size(1))

# %%
# plot the data and W before training

x = np.linspace(-5,5,100)
y = np.zeros(100,) 
plt.plot(x, y, '-r', label='W')
plt.title('Graph of W before training for gamma = 1')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.scatter(D1[:,0], D1[:,1])
plt.scatter(D2[:,0], D2[:,1])
plt.grid()
plt.show()

# %%
W = train_perceptron(X,Y, W, 5)
print(W)
# Out:
# Number of changes: 31
# tensor([-5.3260, -7.7723, 15.0000])

# %%
x = np.linspace(-5,5,100)
y = -(W[0].item()/W[1].item())*x - (W[2].item()/W[1].item())
plt.plot(x, y, '-r', label='W')
plt.title('Graph of W after training for gamma = 3')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.scatter(D1[:,0], D1[:,1])
plt.scatter(D2[:,0], D2[:,1])
plt.grid()
plt.show()
